# %%
import pandas as pd
import numpy as np

# %%
# Check and get current working directory
import os
print(os.getcwd())
# Out:
# /content

# %%
# Connecting to google colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Extract dataset from google drive
dataset = '/content/drive/MyDrive/MyDataSet/course_marketing_performance_data.csv'
df = pd.read_csv(dataset)

# %%
df.head()
# Out:
#   Course ID              Course Title Ad Campaign Platform  Ad Spend ($)  \
# 0    C-1001            Advanced Excel   LinkedIn Sponsored         89.58
# 1    C-1003         SQL for Beginners         Facebook Ads        452.90
# 2    C-1009  Remote Work Productivity         Facebook Ads       1398.07
# 3    C-1001            Advanced Excel        Google Search        265.73
# 4    C-1008        UI/UX Fundamentals          Email Blast        303.76
#
#    Impressions  Clicks  Landing Page Views  Sign-ups  Conversion Rate (%)  \
# 0         2639     164                 153        75                49.02
# 1        10144     323                 238        53                22.27
# 2        28651    2697                2365       492                20.80
# 3        15328    1939                1460       398                27.26
# 4        14031     737                 612       228                37.25
#
#        Location        Date
# 0  Johannesburg  09/06/2025
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Course ID             3000 non-null   object
#  1   Course Title          3000 non-null   object
#  2   Ad Campaign Platform  3000 non-null   object
#  3   Ad Spend ($)          3000 non-null   float64
#  4   Impressions           3000 non-null   int64
#  5   Clicks                3000 non-null   int64
#  6   Landing Page Views    3000 non-null   int64
#  7   Sign-ups              3000 non-null   int64
#  8   Conversion Rate (%)   3000 non-null   float64
#  9   Location              3000 non-null   object
#  10  Date                  3000 non-null   object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 257.9+ KB

# %%
df.isnull().sum()
# Out:
# Course ID               0
# Course Title            0
# Ad Campaign Platform    0
# Ad Spend ($)            0
# Impressions             0
# Clicks                  0
# Landing Page Views      0
# Sign-ups                0
# Conversion Rate (%)     0
# Location                0
# Date                    0
# dtype: int64

# %%
df.describe()
# Out:
#        Ad Spend ($)   Impressions       Clicks  Landing Page Views  \
# count   3000.000000   3000.000000  3000.000000         3000.000000
# mean     759.021580  25595.879667  2049.281333         1685.672667
# std      539.803485  14350.125522  1657.780883         1374.848164
# min       11.150000   1006.000000    13.000000           10.000000
# 25%      329.895000  12864.750000   697.500000          568.750000
# 50%      633.585000  25735.000000  1593.500000         1315.000000
# 75%     1091.280000  38333.250000  2997.750000         2460.250000
# max     2437.830000  49948.000000  7195.000000         6424.000000
#
#           Sign-ups  Conversion Rate (%)
# count  3000.000000          3000.000000
# mean    674.848333            39.781163
# std     612.096893            11.620962
# min       3.000000            17.950000
# 25%     204.000000            29.530000
# 50%     486.500000            39.565000
# 75%     952.000000            50.000000
# ...

# %%
# Displaying selected columns from a table
df[['Date', 'Impressions']]
# Out:
#             Date  Impressions
# 0     09/06/2025         2639
# 1     10/06/2025        10144
# 2     09/07/2025        28651
# 3     23/05/2025        15328
# 4     04/06/2025        14031
# ...          ...          ...
# 2995  16/06/2025        31330
# 2996  03/07/2025         6548
# 2997  06/05/2025        22855
# 2998  06/06/2025        38056
# 2999  23/05/2025         8958
#
# [3000 rows x 2 columns]

# %%
# Displaying selected row from a table
df.iloc[0]
# Out:
# Course ID                           C-1001
# Course Title                Advanced Excel
# Ad Campaign Platform    LinkedIn Sponsored
# Ad Spend ($)                         89.58
# Impressions                           2639
# Clicks                                 164
# Landing Page Views                     153
# Sign-ups                                75
# Conversion Rate (%)                  49.02
# Location                      Johannesburg
# Date                            09/06/2025
# Name: 0, dtype: object

# %%
# Displaying selected row from a table and converting to list
list(df.iloc[0])
# Out:
# ['C-1001',
#  'Advanced Excel',
#  'LinkedIn Sponsored',
#  np.float64(89.58),
#  np.int64(2639),
#  np.int64(164),
#  np.int64(153),
#  np.int64(75),
#  np.float64(49.02),
#  'Johannesburg',
#  '09/06/2025']

# %%
df.head()
# Out:
#   Course ID              Course Title Ad Campaign Platform  Ad Spend ($)  \
# 0    C-1001            Advanced Excel   LinkedIn Sponsored         89.58
# 1    C-1003         SQL for Beginners         Facebook Ads        452.90
# 2    C-1009  Remote Work Productivity         Facebook Ads       1398.07
# 3    C-1001            Advanced Excel        Google Search        265.73
# 4    C-1008        UI/UX Fundamentals          Email Blast        303.76
#
#    Impressions  Clicks  Landing Page Views  Sign-ups  Conversion Rate (%)  \
# 0         2639     164                 153        75                49.02
# 1        10144     323                 238        53                22.27
# 2        28651    2697                2365       492                20.80
# 3        15328    1939                1460       398                27.26
# 4        14031     737                 612       228                37.25
#
#        Location        Date
# 0  Johannesburg  09/06/2025
# ...

# %%
df['Course Title'].value_counts()
# Out:
# Course Title
# Data Visualization with Power BI    328
# Graphic Design Essentials           318
# Advanced Excel                      315
# Project Management 101              312
# AI for Non-Techies                  310
# UI/UX Fundamentals                  302
# Digital Marketing Basics            290
# SQL for Beginners                   281
# Intro to Python                     272
# Remote Work Productivity            272
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Course ID              Course Title Ad Campaign Platform  Ad Spend ($)  \
# 0    C-1001            Advanced Excel   LinkedIn Sponsored         89.58
# 1    C-1003         SQL for Beginners         Facebook Ads        452.90
# 2    C-1009  Remote Work Productivity         Facebook Ads       1398.07
# 3    C-1001            Advanced Excel        Google Search        265.73
# 4    C-1008        UI/UX Fundamentals          Email Blast        303.76
#
#    Impressions  Clicks  Landing Page Views  Sign-ups  Conversion Rate (%)  \
# 0         2639     164                 153        75                49.02
# 1        10144     323                 238        53                22.27
# 2        28651    2697                2365       492                20.80
# 3        15328    1939                1460       398                27.26
# 4        14031     737                 612       228                37.25
#
#        Location        Date
# 0  Johannesburg  09/06/2025
# ...

# %%
# Displaying the item on a particular row by column
df.iloc[1]['Date']
# Out:
# '10/06/2025'

# %%
# Filtering by column
df[df['Course Title'] == 'Advanced Excel']
# Out:
#      Course ID    Course Title Ad Campaign Platform  Ad Spend ($)  \
# 0       C-1001  Advanced Excel   LinkedIn Sponsored         89.58
# 3       C-1001  Advanced Excel        Google Search        265.73
# 8       C-1001  Advanced Excel    Instagram Stories        299.65
# 13      C-1001  Advanced Excel        Google Search        187.64
# 14      C-1001  Advanced Excel         Facebook Ads        374.10
# ...        ...             ...                  ...           ...
# 2945    C-1001  Advanced Excel         Facebook Ads        476.85
# 2950    C-1001  Advanced Excel   LinkedIn Sponsored        375.59
# 2955    C-1001  Advanced Excel          Email Blast        777.44
# 2976    C-1001  Advanced Excel   LinkedIn Sponsored       1389.95
# 2997    C-1001  Advanced Excel          Email Blast        370.79
#
#       Impressions  Clicks  Landing Page Views  Sign-ups  Conversion Rate (%)  \
# 0            2639     164                 153        75                49.02
# ...

# %%
df[(df['Course Title'] == 'Advanced Excel') & (df['Location'] == 'Abuja')]
# Out:
#      Course ID    Course Title Ad Campaign Platform  Ad Spend ($)  \
# 14      C-1001  Advanced Excel         Facebook Ads        374.10
# 61      C-1001  Advanced Excel        Google Search        802.55
# 222     C-1001  Advanced Excel   LinkedIn Sponsored       1406.53
# 297     C-1001  Advanced Excel          Email Blast       1100.76
# 330     C-1001  Advanced Excel   LinkedIn Sponsored        524.06
# 346     C-1001  Advanced Excel    Instagram Stories        286.90
# 354     C-1001  Advanced Excel    Instagram Stories         71.32
# 377     C-1001  Advanced Excel          Email Blast       1599.53
# 422     C-1001  Advanced Excel        Google Search        124.29
# 442     C-1001  Advanced Excel    Instagram Stories       1039.90
# 498     C-1001  Advanced Excel   LinkedIn Sponsored        156.58
# 542     C-1001  Advanced Excel          Email Blast        493.31
# 654     C-1001  Advanced Excel    Instagram Stories        621.03
# ...

# %%
df[(df['Course Title'] == 'Advanced Excel')| (df['Location'] == 'Abuja')]
# Out:
#      Course ID              Course Title Ad Campaign Platform  Ad Spend ($)  \
# 0       C-1001            Advanced Excel   LinkedIn Sponsored         89.58
# 3       C-1001            Advanced Excel        Google Search        265.73
# 4       C-1008        UI/UX Fundamentals          Email Blast        303.76
# 8       C-1001            Advanced Excel    Instagram Stories        299.65
# 13      C-1001            Advanced Excel        Google Search        187.64
# ...        ...                       ...                  ...           ...
# 2976    C-1001            Advanced Excel   LinkedIn Sponsored       1389.95
# 2979    C-1005    Project Management 101    Instagram Stories        755.84
# 2981    C-1009  Remote Work Productivity        Google Search        231.61
# 2994    C-1000           Intro to Python        Google Search        561.44
# 2997    C-1001            Advanced Excel          Email Blast        370.79
#
# ...

# %%
# Select rows from a dataframe given the condition that the location starts with N
df[df['Location'].str.startswith('N')]
# Out:
#      Course ID                      Course Title Ad Campaign Platform  \
# 1       C-1003                 SQL for Beginners         Facebook Ads
# 8       C-1001                    Advanced Excel    Instagram Stories
# 10      C-1000                   Intro to Python    Instagram Stories
# 28      C-1002  Data Visualization with Power BI    Instagram Stories
# 34      C-1008                UI/UX Fundamentals          Email Blast
# ...        ...                               ...                  ...
# 2969    C-1004          Digital Marketing Basics   LinkedIn Sponsored
# 2971    C-1003                 SQL for Beginners          Email Blast
# 2977    C-1003                 SQL for Beginners          Email Blast
# 2990    C-1008                UI/UX Fundamentals    Instagram Stories
# 2997    C-1001                    Advanced Excel          Email Blast
#
#       Ad Spend ($)  Impressions  Clicks  Landing Page Views  Sign-ups  \
# ...

# %%
# Select rows from a dataframe given the condition that the location ends with 'a'
df[df['Location'].str.endswith('a')]
# Out:
#      Course ID              Course Title Ad Campaign Platform  Ad Spend ($)  \
# 4       C-1008        UI/UX Fundamentals          Email Blast        303.76
# 14      C-1001            Advanced Excel         Facebook Ads        374.10
# 15      C-1004  Digital Marketing Basics   LinkedIn Sponsored        745.43
# 20      C-1003         SQL for Beginners   LinkedIn Sponsored         38.92
# 22      C-1003         SQL for Beginners    Instagram Stories       1693.54
# ...        ...                       ...                  ...           ...
# 2981    C-1009  Remote Work Productivity        Google Search        231.61
# 2985    C-1009  Remote Work Productivity    Instagram Stories       1871.86
# 2986    C-1006        AI for Non-Techies         Facebook Ads        619.25
# 2992    C-1009  Remote Work Productivity   LinkedIn Sponsored        789.18
# 2994    C-1000           Intro to Python        Google Search        561.44
#
# ...

# %%
# Select rows from a dataframe given the condition that the location does not end with 'a' using ~
df[~df['Location'].str.endswith('a')]
# Out:
#      Course ID              Course Title Ad Campaign Platform  Ad Spend ($)  \
# 0       C-1001            Advanced Excel   LinkedIn Sponsored         89.58
# 1       C-1003         SQL for Beginners         Facebook Ads        452.90
# 2       C-1009  Remote Work Productivity         Facebook Ads       1398.07
# 3       C-1001            Advanced Excel        Google Search        265.73
# 5       C-1003         SQL for Beginners          Email Blast        750.46
# ...        ...                       ...                  ...           ...
# 2995    C-1000           Intro to Python          Email Blast        447.59
# 2996    C-1000           Intro to Python         Facebook Ads        111.37
# 2997    C-1001            Advanced Excel          Email Blast        370.79
# 2998    C-1004  Digital Marketing Basics    Instagram Stories        387.63
# 2999    C-1000           Intro to Python          Email Blast        203.15
#
# ...

# %%
df[df['Ad Spend ($)'] > 500]
# Out:
#      Course ID                      Course Title Ad Campaign Platform  \
# 2       C-1009          Remote Work Productivity         Facebook Ads
# 5       C-1003                 SQL for Beginners          Email Blast
# 9       C-1005            Project Management 101          Email Blast
# 10      C-1000                   Intro to Python    Instagram Stories
# 12      C-1009          Remote Work Productivity          Email Blast
# ...        ...                               ...                  ...
# 2989    C-1006                AI for Non-Techies    Instagram Stories
# 2991    C-1002  Data Visualization with Power BI   LinkedIn Sponsored
# 2992    C-1009          Remote Work Productivity   LinkedIn Sponsored
# 2993    C-1009          Remote Work Productivity          Email Blast
# 2994    C-1000                   Intro to Python        Google Search
#
#       Ad Spend ($)  Impressions  Clicks  Landing Page Views  Sign-ups  \
# ...

# %%
df[df['Ad Spend ($)'] >= 500]
# Out:
#      Course ID                      Course Title Ad Campaign Platform  \
# 2       C-1009          Remote Work Productivity         Facebook Ads
# 5       C-1003                 SQL for Beginners          Email Blast
# 9       C-1005            Project Management 101          Email Blast
# 10      C-1000                   Intro to Python    Instagram Stories
# 12      C-1009          Remote Work Productivity          Email Blast
# ...        ...                               ...                  ...
# 2989    C-1006                AI for Non-Techies    Instagram Stories
# 2991    C-1002  Data Visualization with Power BI   LinkedIn Sponsored
# 2992    C-1009          Remote Work Productivity   LinkedIn Sponsored
# 2993    C-1009          Remote Work Productivity          Email Blast
# 2994    C-1000                   Intro to Python        Google Search
#
#       Ad Spend ($)  Impressions  Clicks  Landing Page Views  Sign-ups  \
# ...

# %%
df[df['Ad Spend ($)'] != 500]
# Out:
#      Course ID              Course Title Ad Campaign Platform  Ad Spend ($)  \
# 0       C-1001            Advanced Excel   LinkedIn Sponsored         89.58
# 1       C-1003         SQL for Beginners         Facebook Ads        452.90
# 2       C-1009  Remote Work Productivity         Facebook Ads       1398.07
# 3       C-1001            Advanced Excel        Google Search        265.73
# 4       C-1008        UI/UX Fundamentals          Email Blast        303.76
# ...        ...                       ...                  ...           ...
# 2995    C-1000           Intro to Python          Email Blast        447.59
# 2996    C-1000           Intro to Python         Facebook Ads        111.37
# 2997    C-1001            Advanced Excel          Email Blast        370.79
# 2998    C-1004  Digital Marketing Basics    Instagram Stories        387.63
# 2999    C-1000           Intro to Python          Email Blast        203.15
#
# ...

# %%
df.shape
# Out:
# (3000, 11)

# %%
df['Location'].unique()
# Out:
# array(['Johannesburg', 'Nairobi', 'Lagos', 'Abuja', 'Cairo', 'Kigali',
#        'Accra', 'Cape Town'], dtype=object)

# %%
# Select information from dataframe where the location is either Lagos or Abuja
df[df['Location'].isin(['Lagos', 'Abuja'])]
# Out:
#      Course ID              Course Title Ad Campaign Platform  Ad Spend ($)  \
# 2       C-1009  Remote Work Productivity         Facebook Ads       1398.07
# 3       C-1001            Advanced Excel        Google Search        265.73
# 4       C-1008        UI/UX Fundamentals          Email Blast        303.76
# 14      C-1001            Advanced Excel         Facebook Ads        374.10
# 19      C-1008        UI/UX Fundamentals   LinkedIn Sponsored        225.26
# ...        ...                       ...                  ...           ...
# 2979    C-1005    Project Management 101    Instagram Stories        755.84
# 2981    C-1009  Remote Work Productivity        Google Search        231.61
# 2989    C-1006        AI for Non-Techies    Instagram Stories       1298.17
# 2994    C-1000           Intro to Python        Google Search        561.44
# 2999    C-1000           Intro to Python          Email Blast        203.15
#
# ...

# %%
# Convert all location to upper case
df['Location'] = df['Location'].str.upper()
df.head()
# Out:
#   Course ID              Course Title Ad Campaign Platform  Ad Spend ($)  \
# 0    C-1001            Advanced Excel   LinkedIn Sponsored         89.58
# 1    C-1003         SQL for Beginners         Facebook Ads        452.90
# 2    C-1009  Remote Work Productivity         Facebook Ads       1398.07
# 3    C-1001            Advanced Excel        Google Search        265.73
# 4    C-1008        UI/UX Fundamentals          Email Blast        303.76
#
#    Impressions  Clicks  Landing Page Views  Sign-ups  Conversion Rate (%)  \
# 0         2639     164                 153        75                49.02
# 1        10144     323                 238        53                22.27
# 2        28651    2697                2365       492                20.80
# 3        15328    1939                1460       398                27.26
# 4        14031     737                 612       228                37.25
#
#        Location        Date
# 0  JOHANNESBURG  09/06/2025
# ...

# %%
df.head()
# Out:
#   Course ID              Course Title Ad Campaign Platform  Ad Spend ($)  \
# 0    C-1001            Advanced Excel   LinkedIn Sponsored         89.58
# 1    C-1003         SQL for Beginners         Facebook Ads        452.90
# 2    C-1009  Remote Work Productivity         Facebook Ads       1398.07
# 3    C-1001            Advanced Excel        Google Search        265.73
# 4    C-1008        UI/UX Fundamentals          Email Blast        303.76
#
#    Impressions  Clicks  Landing Page Views  Sign-ups  Conversion Rate (%)  \
# 0         2639     164                 153        75                49.02
# 1        10144     323                 238        53                22.27
# 2        28651    2697                2365       492                20.80
# 3        15328    1939                1460       398                27.26
# 4        14031     737                 612       228                37.25
#
#        Location        Date
# 0  JOHANNESBURG  09/06/2025
# ...

# %%
# Creating new column named New Location
df['New Location'] = df['Location']

# %%
df.head()
# Out:
#   Course ID              Course Title Ad Campaign Platform  Ad Spend ($)  \
# 0    C-1001            Advanced Excel   LinkedIn Sponsored         89.58
# 1    C-1003         SQL for Beginners         Facebook Ads        452.90
# 2    C-1009  Remote Work Productivity         Facebook Ads       1398.07
# 3    C-1001            Advanced Excel        Google Search        265.73
# 4    C-1008        UI/UX Fundamentals          Email Blast        303.76
#
#    Impressions  Clicks  Landing Page Views  Sign-ups  Conversion Rate (%)  \
# 0         2639     164                 153        75                49.02
# 1        10144     323                 238        53                22.27
# 2        28651    2697                2365       492                20.80
# 3        15328    1939                1460       398                27.26
# 4        14031     737                 612       228                37.25
#
#        Location        Date  New Location
# ...

# %%
# Removing a column from a dataframe without altering the table
df.drop('New Location', axis = 1)
# Out:
#      Course ID              Course Title Ad Campaign Platform  Ad Spend ($)  \
# 0       C-1001            Advanced Excel   LinkedIn Sponsored         89.58
# 1       C-1003         SQL for Beginners         Facebook Ads        452.90
# 2       C-1009  Remote Work Productivity         Facebook Ads       1398.07
# 3       C-1001            Advanced Excel        Google Search        265.73
# 4       C-1008        UI/UX Fundamentals          Email Blast        303.76
# ...        ...                       ...                  ...           ...
# 2995    C-1000           Intro to Python          Email Blast        447.59
# 2996    C-1000           Intro to Python         Facebook Ads        111.37
# 2997    C-1001            Advanced Excel          Email Blast        370.79
# 2998    C-1004  Digital Marketing Basics    Instagram Stories        387.63
# 2999    C-1000           Intro to Python          Email Blast        203.15
#
# ...

# %%
df.head()
# Out:
#   Course ID              Course Title Ad Campaign Platform  Ad Spend ($)  \
# 0    C-1001            Advanced Excel   LinkedIn Sponsored         89.58
# 1    C-1003         SQL for Beginners         Facebook Ads        452.90
# 2    C-1009  Remote Work Productivity         Facebook Ads       1398.07
# 3    C-1001            Advanced Excel        Google Search        265.73
# 4    C-1008        UI/UX Fundamentals          Email Blast        303.76
#
#    Impressions  Clicks  Landing Page Views  Sign-ups  Conversion Rate (%)  \
# 0         2639     164                 153        75                49.02
# 1        10144     323                 238        53                22.27
# 2        28651    2697                2365       492                20.80
# 3        15328    1939                1460       398                27.26
# 4        14031     737                 612       228                37.25
#
#        Location        Date  New Location
# ...

# %%
# Removing a column from a dataframe altering the table from the original columns
df.drop('New Location', axis = 1, inplace = True)

# %%
df.head()
# Out:
#   Course ID              Course Title Ad Campaign Platform  Ad Spend ($)  \
# 0    C-1001            Advanced Excel   LinkedIn Sponsored         89.58
# 1    C-1003         SQL for Beginners         Facebook Ads        452.90
# 2    C-1009  Remote Work Productivity         Facebook Ads       1398.07
# 3    C-1001            Advanced Excel        Google Search        265.73
# 4    C-1008        UI/UX Fundamentals          Email Blast        303.76
#
#    Impressions  Clicks  Landing Page Views  Sign-ups  Conversion Rate (%)  \
# 0         2639     164                 153        75                49.02
# 1        10144     323                 238        53                22.27
# 2        28651    2697                2365       492                20.80
# 3        15328    1939                1460       398                27.26
# 4        14031     737                 612       228                37.25
#
#        Location        Date
# 0  JOHANNESBURG  09/06/2025
# ...

# %%
# Saving your new dataframe. If you want index included then input true otherwise input false
df.to_csv('Marketing Performance', index = False)
